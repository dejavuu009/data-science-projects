# %% [markdown]
# <a href="https://colab.research.google.com/github/dejavuu009/data-science-projects/blob/main/MachineLearning/backward_elimination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

sns.set()
np.random.seed(42)
np.set_printoptions(suppress=True, precision=4)
sklearn.__version__
# Out:
# '1.6.1'

# %%
df_raw = pd.read_csv('https://storage.googleapis.com/esmartdata-courses-files/ml-course/insurance.csv')
df_raw.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df = df_raw.copy()
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df[df['charges'] == 1639.5631 ]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 195   19  male  30.59         0     no  northwest  1639.5631
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
cat_cols
# Out:
# ['sex', 'smoker', 'region']

# %%
for col in cat_cols:
    df[col] = df[col].astype('category')
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   category
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: category(1), float64(2), int64(2), object(2)
# memory usage: 74.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   category
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   category
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: category(2), float64(2), int64(2), object(1)
# memory usage: 65.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   category
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   category
#  5   region    1337 non-null   category
#  6   charges   1337 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 56.6 KB

# %%
df.describe().T
# Out:
#            count          mean           std        min       25%        50%  \
# age       1337.0     39.222139     14.044333    18.0000    27.000    39.0000
# bmi       1337.0     30.663452      6.100468    15.9600    26.290    30.4000
# children  1337.0      1.095737      1.205571     0.0000     0.000     1.0000
# charges   1337.0  13279.121487  12110.359656  1121.8739  4746.344  9386.1613
#
#                   75%          max
# age          51.00000     64.00000
# bmi          34.70000     53.13000
# children      2.00000      5.00000
# charges   16657.71745  63770.42801

# %%
df.describe(include='category').T
# Out:
#        count unique        top  freq
# sex     1337      2       male   675
# smoker  1337      2         no  1063
# region  1337      4  southeast   364

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.sex.value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
df.smoker.value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
df.smoker.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.charges.plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import plotly.express as px

# %%
px.histogram(df, x='charges', nbins=50, facet_col='smoker', facet_row='sex', width=700, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bfcd0842-012c-46e9-9b12-f88422220ebd" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfcd0842-012c-46e9-9b12-f88422220ebd")) {                    Plotly.newPlot(                        "bfcd0842-012c-46e9-9b12-f88422220ebd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sex=female\u003cbr\u003esmoker=yes\u003cbr\u003echarges=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[16884.924,27808.7251,37701.8768,23244.7902,14711.7438,16577.7795,39836.519,43578.9394,47291.055,30942.1918,19107.7796,17081.08,32734.1863,19964.7463,21348.706,36149.4835,48824.45,37133.8982,19444.2658,38511.6283,29523.1656,47305.305,17085.2676,22331.5668,47896.79135,24873.3849,34838.873,47928.03,48517.56315,13844.506,18033.9679,21659.9301,15006.57945,19594.80965,14455.64405,18608.262,28950.4692,37079.372,19521.9682,48885.13561,63770.42801,45863.205,39983.42595,58571.07448,43943.8761,15359.1045,17468.9839,25678.77845,42969.8527,34439.8559,42983.4585,24667.419,27037.9141,40003.33225,46200.9851,44400.4064,40
 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1337 rows x 9 columns]

# %%
corr = df_dummies.corr()
corr
# Out:
#                        age       bmi  children   charges  sex_male  \
# age               1.000000  0.108491  0.041536  0.298309 -0.019814
# bmi               0.108491  1.000000  0.011081  0.196236  0.046541
# children          0.041536  0.011081  1.000000  0.067390  0.017848
# charges           0.298309  0.196236  0.067390  1.000000  0.058046
# sex_male         -0.019814  0.046541  0.017848  0.058046  1.000000
# smoker_yes       -0.025587  0.001659  0.007331  0.787234  0.076596
# region_northwest  0.001495 -0.138620  0.026044 -0.038695 -0.012482
# region_southeast -0.012311  0.271328 -0.023492  0.073577  0.017578
# region_southwest  0.009415 -0.004325  0.021538 -0.043637 -0.003767
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.025587          0.001495         -0.012311
# bmi                 0.001659         -0.138620          0.271328
# children            0.007331          0.026044         -0.023492
# charges             0.787234         -0.038695          0.073577
# sex_male            0.076596         -0.012482          0.017578
# smoker_yes          1.000000         -0.036321          0.068282
# region_northwest   -0.036321          1.000000         -0.345909
# region_southeast    0.068282         -0.345909          1.000000
# region_southwest   -0.037168         -0.320493         -0.346614
#
#                   region_southwest
# age                       0.009415
# bmi                      -0.004325
# children                  0.021538
# charges                  -0.043637
# sex_male                 -0.003767
# smoker_yes               -0.037168
# region_northwest         -0.320493
# region_southeast         -0.346614
# region_southwest          1.000000

# %%
sns.set(style="white")
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(8, 6))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
df_dummies.corr()['charges'].sort_values(ascending=False)
# Out:
# charges             1.000000
# smoker_yes          0.787234
# age                 0.298309
# bmi                 0.196236
# region_southeast    0.073577
# children            0.067390
# sex_male            0.058046
# region_northwest   -0.038695
# region_southwest   -0.043637
# Name: charges, dtype: float64

# %%
sns.set()

# %%
df_dummies.corr()['charges'].sort_values()[:-1].plot(kind='barh')
# Out:
# <Axes: >

# %%
data = df_dummies.copy()
target = data.pop('charges')
data.head()
# Out:
#    age  bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19   27         0         0           1                 0
# 1   18   33         1         1           0                 0
# 2   28   33         3         1           0                 0
# 3   33   22         0         1           0                 1
# 4   32   28         0         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
from re import X
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# %%
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}')
# Out:
# X_train shape: (1069, 8)
# y_train shape: (1069,)
# X_test shape: (268, 8)

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f'regression.coef_: {regression.coef_}')
print(f'regression.intercept_: {regression.intercept_}')
# Out:
# regression.coef_: [  248.4086   317.6745   534.4252  -101.0649 23087.1249  -387.1653
#   -851.3662  -676.845 ]
# regression.intercept_: -10910.071093903349

# %%
print(f'R2 score: {regression.score(X_train, y_train):.4f}')
# Out:
# R2 score: 0.7299

# %%
y_pred = regression.predict(X_test)
y_pred[:10]
# Out:
# array([ 8149.7234,  5696.4963, 14411.1591, 31793.6989,  8978.6461,
#        13132.3257, 30395.5845,  1502.2612, 10573.1649, 11271.8808])

# %%
y_true = y_test.copy()
predictions = pd.DataFrame(data={'y_true': y_true, 'y_pred': y_pred})
predictions['error'] = predictions['y_true'] -  predictions['y_pred']
predictions.head()
# Out:
#       y_true        y_pred        error
# 900     8688   8149.723413   538.276587
# 1064    5708   5696.496322    11.503678
# 1256   11436  14411.159132 -2975.159132
# 298    38746  31793.698864  6952.301136
# 237     4463   8978.646086 -4515.646086

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

# %%
print(f'mse: {mse:.2f}')
print(f'mae: {mae:.2f}')
# Out:
# mse: 35475294.14
# mae: 4171.80

# %%
import statsmodels.api as sm

X_train_ols = X_train.copy()
X_train_ols = X_train_ols.values
X_train_ols = sm.add_constant(X_train_ols)
X_train_ols
# Out:
# array([[ 1., 23., 24., ...,  0.,  0.,  0.],
#        [ 1., 21., 25., ...,  0.,  0.,  0.],
#        [ 1., 52., 37., ...,  1.,  0.,  0.],
#        ...,
#        [ 1., 20., 22., ...,  0.,  0.,  1.],
#        [ 1., 38., 28., ...,  0.,  0.,  1.],
#        [ 1., 35., 35., ...,  0.,  1.,  0.]])

# %%
ols = sm.OLS(endog=y_train, exog=X_train_ols).fit()
predictors = ['const'] + list(X_train.columns)
print(ols.summary(xname=predictors))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     358.0
# Date:                Mon, 25 Aug 2025   Prob (F-statistic):          5.30e-295
# Time:                        10:09:25   Log-Likelihood:                -10831.
# No. Observations:                1069   AIC:                         2.168e+04
# Df Residuals:                    1060   BIC:                         2.172e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.091e+04   1100.397     -9.915      0.000   -1.31e+04   -8750.866
# age                248.4086     13.506     18.393      0.000     221.907     274.910
# bmi                317.6745     32.465      9.785      0.000     253.972     381.377
# children           534.4252    156.806      3.408      0.001     226.739     842.111
# sex_male          -101.0649    375.811     -0.269      0.788    -838.483     636.353
# smoker_yes        2.309e+04    471.102     49.007      0.000    2.22e+04     2.4e+04
# region_northwest  -387.1653    538.024     -0.720      0.472   -1442.878     668.548
# region_southeast  -851.3662    546.498     -1.558      0.120   -1923.707     220.975
# region_southwest  -676.8450    539.669     -1.254      0.210   -1735.786     382.096
# ==============================================================================
# Omnibus:                      266.136   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              639.726
# Skew:                           1.329   Prob(JB):                    1.22e-139
# Kurtosis:                       5.702   Cond. No.                         306.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_selected = X_train_ols[:, [0, 1, 2, 3, 5, 6, 7, 8]]
predictors.remove('sex_male')

ols = sm.OLS(endog=y_train, exog=X_selected).fit()
print(ols.summary(xname=predictors))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     409.5
# Date:                Mon, 25 Aug 2025   Prob (F-statistic):          2.62e-296
# Time:                        10:09:32   Log-Likelihood:                -10831.
# No. Observations:                1069   AIC:                         2.168e+04
# Df Residuals:                    1061   BIC:                         2.172e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.095e+04   1088.657    -10.060      0.000   -1.31e+04   -8816.138
# age                248.5260     13.493     18.419      0.000     222.050     275.002
# bmi                317.2189     32.406      9.789      0.000     253.631     380.806
# children           534.4792    156.738      3.410      0.001     226.928     842.030
# smoker_yes        2.308e+04    469.199     49.183      0.000    2.22e+04     2.4e+04
# region_northwest  -387.9397    537.781     -0.721      0.471   -1443.175     667.295
# region_southeast  -848.2406    546.136     -1.553      0.121   -1919.869     223.388
# region_southwest  -673.7533    539.311     -1.249      0.212   -1731.990     384.484
# ==============================================================================
# Omnibus:                      266.314   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              640.590
# Skew:                           1.329   Prob(JB):                    7.90e-140
# Kurtosis:                       5.705   Cond. No.                         303.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_selected = X_train_ols[:, [0, 1, 2, 3, 5, 7, 8]]
predictors.remove('region_northwest')

ols = sm.OLS(endog=y_train, exog=X_selected).fit()
print(ols.summary(xname=predictors))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     477.9
# Date:                Mon, 25 Aug 2025   Prob (F-statistic):          1.49e-297
# Time:                        10:09:54   Log-Likelihood:                -10831.
# No. Observations:                1069   AIC:                         2.168e+04
# Df Residuals:                    1062   BIC:                         2.171e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.114e+04   1057.622    -10.531      0.000   -1.32e+04   -9062.507
# age                248.6168     13.489     18.431      0.000     222.148     275.085
# bmi                316.6421     32.389      9.776      0.000     253.088     380.196
# children           532.4889    156.678      3.399      0.001     225.055     839.923
# smoker_yes        2.309e+04    468.714     49.262      0.000    2.22e+04     2.4e+04
# region_southeast  -648.7463    470.834     -1.378      0.169   -1572.617     275.124
# region_southwest  -474.8269    463.373     -1.025      0.306   -1384.058     434.404
# ==============================================================================
# Omnibus:                      265.855   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              638.447
# Skew:                           1.328   Prob(JB):                    2.31e-139
# Kurtosis:                       5.699   Cond. No.                         290.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_numpy = X_train.values
X_train_numpy = sm.add_constant(X_train_numpy)
num_vars = len(X_train_numpy[0])

predictors = ['const'] + list(X_train.columns)
sl = 0.05

for i in range(0, num_vars):
    ols = sm.OLS(endog=y_train, exog=X_train_numpy).fit()
    max_pval = max(ols.pvalues.astype('float'))
    if max_pval > sl:
        for j in range(0, num_vars - i):
            if ols.pvalues[j].astype('float') == max_pval:
                X_train_numpy = np.delete(X_train_numpy, j, axis=1)
                predictors.remove(predictors[j])

print(ols.summary(xname=predictors))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     716.1
# Date:                Mon, 25 Aug 2025   Prob (F-statistic):          6.30e-300
# Time:                        10:14:25   Log-Likelihood:                -10832.
# No. Observations:                1069   AIC:                         2.167e+04
# Df Residuals:                    1064   BIC:                         2.170e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.108e+04   1047.722    -10.571      0.000   -1.31e+04   -9019.570
# age          249.4016     13.473     18.511      0.000     222.965     275.838
# bmi          303.8355     30.994      9.803      0.000     243.019     364.652
# children     539.5312    156.623      3.445      0.001     232.206     846.856
# smoker_yes  2.305e+04    467.074     49.352      0.000    2.21e+04     2.4e+04
# ==============================================================================
# Omnibus:                      265.208   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              635.805
# Skew:                           1.325   Prob(JB):                    8.64e-139
# Kurtosis:                       5.693   Cond. No.                         286.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /tmp/ipython-input-3227885750.py:13: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipython-input-3227885750.py:13: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipython-input-3227885750.py:13: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipython-input-3227885750.py:13: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
ols.save('model.pickle')
